# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('final_vg.csv')
data.head(2)
# Out:
#    Rank                          Name Platform    Year     Genre  Publisher  \
# 0  2061                          1942      NES  1985.0   Shooter     Capcom
# 1  9137  ¡Shin Chan Flipa en colores!       DS  2007.0  Platform  505 Games
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  4.569217  3.033887  3.439352     1.991671     12.802935
# 1  2.076955  1.493442  3.033887     0.394830      7.034163

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16652.000000  16381.000000  16652.000000  16652.000000  16652.000000
# mean    8283.409620   2006.390513      2.752314      1.996875      2.499677
# std     4794.471477      5.863261      1.327002      1.322972      1.164023
# min        1.000000   1980.000000      0.140000      0.010000      0.000000
# 25%     4129.750000   2003.000000      1.781124      1.087977      1.781124
# 50%     8273.500000   2007.000000      2.697415      1.714664      2.480356
# 75%    12436.250000   2010.000000      3.677290      2.795123      3.176299
# max    16600.000000   2020.000000      8.725452      8.367985     12.722984
#
#         Other_Sales  Global_Sales
# count  16652.000000  16652.000000
# mean       1.151829      8.457873
# std        1.054813      3.717756
# min       -0.474276      0.240000
# 25%        0.394830      5.580341
# 50%        0.491870      7.536614
# 75%        1.781124     11.227334
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16652 entries, 0 to 16651
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16652 non-null  int64
#  1   Name          16652 non-null  object
#  2   Platform      16652 non-null  object
#  3   Year          16381 non-null  float64
#  4   Genre         16652 non-null  object
#  5   Publisher     16594 non-null  object
#  6   NA_Sales      16652 non-null  float64
#  7   EU_Sales      16652 non-null  float64
#  8   JP_Sales      16652 non-null  float64
#  9   Other_Sales   16652 non-null  float64
#  10  Global_Sales  16652 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data.shape
# Out:
# (16652, 11)

# %% [markdown]
# # Bar and Pie

# %%
sns.countplot(data=data, x= 'Genre')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Histogram

# %%
data['Year'].nunique()
# Out:
# 41

# %%
plt.hist(data['Year'], bins = 10)
plt.xlabel('Year')
plt.ylabel('Count of games')
plt.show()

# %% [markdown]
# # KDE with histogram

# %%
sns.histplot(data=data, x='Year', bins=10, kde=True)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# # Box plot

# %%
sns.boxplot(data=data, y='Global_Sales')
# Out:
# <Axes: ylabel='Global_Sales'>
