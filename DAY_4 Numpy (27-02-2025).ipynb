# %%
import numpy as np
import pandas as pd

# %%
data = np.loadtxt('fit.txt', dtype=str)
# Out:
# /tmp/ipython-input-291/3399993384.py:1: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   data = np.loadtxt('fit.txt', dtype=str)

# %%
data[:2]
# Out:
# array([['06-10-2017', '5464', 'Neutral', '181', '5', 'Inactive'],
#        ['07-10-2017', '6041', 'Sad', '197', '8', 'Inactive']],
#       dtype='<U10')

# %%
data.shape
# Out:
# (96, 6)

# %%
# what is the avg step count on active days
data[data[:, -1] == 'Active'][:,1:2].astype('int').flatten().mean()
# Out:
# np.float64(3226.5714285714284)

# %%
dates, step_count, mood, calories, sleep, status = data.T

# %%
step_count = step_count.astype('int')
calories = calories.astype('float')
sleep = sleep.astype('int')

# %%
len(data[(step_count > 5000) & (calories > 150)])
# Out:
# 17

# %%
np.min(step_count[sleep < 6])
# Out:
# np.int64(25)

# %%
np.max(step_count[sleep < 6])
# Out:
# np.int64(7422)

# %%
# what are the average calories burnt per hour of sleep on inactive
calories[status == 'Inactive'] / sleep[status == 'Inactive']
# Out:
# array([36.2       , 24.625     ,  0.        , 43.5       , 24.83333333,
#        23.33333333,  5.42857143,  0.2       ,  6.66666667, 12.625     ,
#        30.4       , 16.14285714,  9.8       , 14.33333333,  0.75      ,
#        19.8       , 35.75      , 25.        , 21.5       ,  0.75      ,
#         1.8       ,  1.66666667, 14.4       , 28.2       , 39.        ,
#        11.4       , 18.        , 45.25      , 65.66666667, 65.5       ,
#        17.11111111, 27.4       , 29.        , 32.        , 29.2       ,
#        39.        , 33.4       ,  2.66666667, 19.        ,  6.25      ,
#        13.75      , 25.8       ,  4.2       ,  7.        ,  5.33333333,
#         1.        ,  0.33333333,  3.33333333, 15.66666667, 42.        ,
#         7.66666667,  2.        ,  0.        ,  0.        ])

# %%
# Which mood has the highest average step count ?

# %%
# Is there any co-relation in number of steps and the mood a person has ?
np.average(step_count[mood == 'Neutral'])
# Out:
# np.float64(3153.777777777778)

# %%
np.average(step_count[mood == 'Sad'])
# Out:
# np.float64(2103.0689655172414)

# %%
np.average(step_count[mood == 'Happy'])
# Out:
# np.float64(3392.725)
